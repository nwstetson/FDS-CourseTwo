# %% [markdown]
# # Pandas Review Homework

# %% [markdown]
# Import pandas

# %%
import pandas as pd

# %% [markdown]
# ## 1. Make a data frame from a Python dictionary.

# %% [markdown]
# Create a Python dictionary containing
#
# - the names of four of your friends (real or imaginary)
# - their ages
# - the year they started college
# - their majors

# %%
friends_dict = {'name': ['Ryan', 'Mandy', 'Ian', 'Abby'],
                'age': [21, 21, 20, 20],
                'year': [2019, 2020, 2020, 2021],
                'major': ['EEB', 'EVS', 'Anthro', 'EEB']
               }

# %% [markdown]
# Make a pandas data frame from your dictionary.

# %%
friends_dict = pd.DataFrame(friends_dict)

# %% [markdown]
# Show your new data frame.

# %%
friends_dict
# Out:
#     name  age  year   major
# 0   Ryan   21  2019     EEB
# 1  Mandy   21  2020     EVS
# 2    Ian   20  2020  Anthro
# 3   Abby   20  2021     EEB

# %% [markdown]
# Fetch the ages of all your friends.

# %%
friends_dict["name"]
# Out:
# 0     Ryan
# 1    Mandy
# 2      Ian
# 3     Abby
# Name: name, dtype: object

# %% [markdown]
# Fetch the name of your fourth friend.

# %%
(friends_dict["name"][3])
# Out:
# 'Abby'

# %% [markdown]
# Fetch the age of your third friend.

# %%
(friends_dict["age"][2])
# Out:
# 20

# %% [markdown]
# Compute and show the average age of your friends.

# %%
friends_dict["age"].mean()
# Out:
# 20.5

# %% [markdown]
# ## 2. Find a table of data on Wikipedia and import it.

# %% [markdown]
# Go to Widepedia and find a table of data. It can be anything you want.

# %% [markdown]
# In the cell below, import the data and display it (first and last five rows).

# %%
extinct_dog_breeds = pd.read_clipboard()

extinct_dog_breeds
# Out:
#                                       Name  \
# 0                     African hairless dog
# 1                                   Alaunt
# 2                           Alpine mastiff
# 3                      Argentine Polar Dog
# 4                          Belgian Mastiff
# 5                    Black and Tan Terrier
# 6                             Braque Dupuy
# 7                                Buckhound
# 8                            Bullenbeisser
# 9                             Celtic Hound
# 10                              Chien-gris
# 11                           Chiribaya Dog
# 12                    Córdoba fighting dog
# 13                     Cumberland Sheepdog
# 14                                     Cur
# 15                               Dalbo dog
# 16                             Dogo Cubano
# 17    Dumfriesshire Black and Tan Foxhound
# 18                   English Water Spaniel
# 19                   English White Terrier
# 20                        Fila da Terceira
# 21                             Fuegian dog
# 22                 Grand Fauve de Bretagne
# 23                            Halls Heeler
# 24                         Hare Indian Dog
# 25                        Hawaiian Poi Dog
# 26                      King's White Hound
# 27                                    Kurī
# 28                      Lapponian Shepherd
# 29                                   Limer
# 30                           Marquesan Dog
# 31                                Molossus
# 32                        Moscow Water Dog
# 33                         Norfolk Spaniel
# 34                            Norman Hound
# 35                    North Country Beagle
# 36                 Old Croatian Sighthound
# 37                     Old English Bulldog
# 38                     Old Spanish Pointer
# 39                 Old Welsh Grey Sheepdog
# 40                         Paisley Terrier
# 41                          Polynesian Dog
# 42                                   Rache
# 43                   Rastreador Brasileiro
# 44                     St John's water dog
# 45  Sakhalin Husky (Karafuto Ken in Japan)
# 46                         Salish Wool Dog
# 47                            Sleuth hound
# 48                          Southern Hound
# 49                               Staghound
# 50                            Tahitian Dog
# 51                        Tahltan Bear Dog
# 52                            Talbot Hound
# 53                                Techichi
# 54                                   Tesem
# 55                             Toy Bulldog
# 56                     Toy Trawler Spaniel
# 57                            Turnspit dog
# 58                     Tweed Water Spaniel
# 59                           Welsh Hillman
#
#                                                 Image  \
# 0                                 Africanhairless.jpg
# 1                              Jacopo del Sallaio.jpg
# 2                             1815 Alpine Mastiff.jpg
# 3                                         Simba02.jpg
# 4   Belgian dogs trained to draw quick-firing guns...
# 5               Old English Black and Tan Terrier.jpg
# 6                         Dupuy Pointer from 1915.JPG
# 7   William H Hopkins (active 1853-1890-d. 1892) -...
# 8                                    Bullenbeiser.jpg
# 9   Arrian on coursing - the Cynegeticus of the yo...
# 10                  Gris De Saint-Louis from 1915.JPG
# 11                                                NaN
# 12                                          Patan.jpg
# 13                            Cumberland-sheepdog.jpg
# 14       Cur dog, A general history of quadrupeds.jpg
# 15                                      Dalbohund.jpg
# 16                                    DogoCubano2.jpg
# 17                                                NaN
# 18                          English Water Spaniel.jpg
# 19                      Old English White Terrier.jpg
# 20                               Fila de Terceira.jpg
# 21                             Fuegian dog (1863).jpg
# 22                        Grand Fauve de Bretagne.jpg
# 23  Peaceful rural scene in South East Queensland.jpg
# 24                                  Hareindiandog.jpg
# 25  Hawaiian natives wearing kihei, with animals, ...
# 26  Jean-Baptiste Oudry - La chasse au chevreuilt ...
# 27                             ChiefsWithKuri1828.jpg
# 28                                                NaN
# 29                                          Limer.jpg
# 30  Dog relief from meʻae Iʻipona, Puamaʻu Village...
# 31                Molossian Hound, British Museum.jpg
# 32                                                NaN
# 33                        Dash-II-Norfolk-Spaniel.jpg
# 34                                                NaN
# 35                                   Beagle (PSF).png
# 36                                                NaN
# 37                                CribandRosa1811.jpg
# 38                      Spanish Pointer from 1915.JPG
# 39                                                NaN
# 40                                    Paisley1903.jpg
# 41                                                NaN
# 42                      Rache Historiae Animalium.jpg
# 43                    Rastreadora Brasileira Gaya.jpg
# 44                                   St Johns dog.jpg
# 45                            Sakhalin Husky Jiro.JPG
# 46  PaulKane - A Woman Weaving a Blanket (ROM2005 ...
# 47                                                NaN
# 48                                 Southern Hound.jpg
# 49  John Scott's Stag hound, The sportsman's repos...
# 50  Double canoes. Tipaerua, 1769-71 (crop of dog)...
# 51                       Tahltan Bear Dog sketch2.jpg
# 52        TalbotHound Talbot Shrewsbury Book 1445.png
# 53  Colima - Dog Effigy - Walters 20092051 - Three...
# 54                                   Tesem couple.png
# 55                   Toy Bulldog Little Knot 1903.jpg
# 56                              Toytrawlerspaniel.jpg
# 57                               Turnspitdog-1862.jpg
# 58                            Tweed Water Spaniel.jpg
# 59                                                NaN
#
#                                                 Notes
# 0                                                 NaN
# 1   Large running dogs used during the Middle Ages...
# 2   A mastiff-type dog known in the Western Alps f...
# 3   A long-haired breed developed by the Argentine...
# 4   A mastiff-type breed that was used throughout ...
# 5   A British breed of terrier that was common thr...
# 6   A French breed of pointer from the Poitou regi...
# 7   An English breed of scent hound; used to hunt ...
# 8   A German hunting-mastiff known from the Middle...
# 9   The Celtic hounds were a breed of dogs in Gael...
# 10  A French breed of scenthound known in the Midd...
# 11  A herding breed developed by the Chiribaya cul...
# 12  A fighting dog type developed in Córdoba, Arge...
# 13  A British herding dog from Cumberland that was...
# 14  A British breed of herding dog used by cattle ...
# 15                                                NaN
# 16  A Cuban breed of mastiff originally used for b...
# 17  A British pack of foxhounds from Scotland bred...
# 18  A British breed of gundog that was described a...
# 19  A British breed of terrier from England that w...
# 20  A mastiff-type dog from the Azores,[19] it was...
# 21  A domesticated form of the culpeo (Lycalopex c...
# 22  A French breed of scenthound from Brittany tha...
# 23  An Australian breed of cattle herding dog bred...
# 24                                                NaN
# 25  A Hawaiian pye-dog that was kept by the native...
# 26  A French breed of scent hound that was kept by...
# 27                                                NaN
# 28                                                NaN
# 29  A scenthound in the Middle Ages used to locate...
# 30                                                NaN
# 31  Large dogs kept in the ancient kingdom of Molo...
# 32                                                NaN
# 33                                                NaN
# 34  A large breed of French scent hound from Norma...
# 35  A British medium-sized scenthound that was use...
# 36  A Croatian breed of sighthound used to course ...
# 37  A British breed of specialised small mastiff-t...
# 38  A breed of Spanish pointing dog known from the...
# 39                                                NaN
# 40  A terrier breed from Scotland bred primarily a...
# 41  A catch-all term for four breeds on this list:...
# 42  A British type of hound in the Middle Ages, th...
# 43                                                NaN
# 44  A Canadian breed used by the fishermen of Newf...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  A British medium-sized scenthound that was use...
# 49  An English breed of scent hound that was used ...
# 50                                                NaN
# 51                                                NaN
# 52  A British small to medium-sized white scenthou...
# 53           An ancestor of the modern Chihuahua.[36]
# 54                                                NaN
# 55  A British breed that was a miniaturised versio...
# 56                                                NaN
# 57  A British dog type used in larger kitchens to ...
# 58  A British breed of gundog from the Anglo-Scott...
# 59     A British breed of herding dog from Wales.[40]

# %%
edb_h = extinct_dog_breeds.head(4)
edb_t = extinct_dog_breeds.tail(4)

# %% [markdown]
# ## 3. Load the RMS titanic data and export a subset of columns

# %% [markdown]
# Load the titanic data, make a new `DataFrame` of the fare paid and the survival columns, and export it as a `.csv` file.

# %%
titanic = pd.read_csv("data/titanic.csv") # import data

fare_surv = titanic[['Fare', 'Survived']] # filter out what we want

fare_surv.to_csv('data/fare_surv.csv') # export as csv

# %% [markdown]
# Import your new `.csv` file into a new `DataFrame` and show it (first and last five rows).

# %%
fare_surv = pd.read_csv('data/fare_surv.csv')

# %%
fare_surv
# Out:
#      Unnamed: 0     Fare  Survived
# 0             0   7.2500         0
# 1             1  71.2833         1
# 2             2   7.9250         1
# 3             3  53.1000         1
# 4             4   8.0500         0
# ..          ...      ...       ...
# 886         886  13.0000         0
# 887         887  30.0000         1
# 888         888  23.4500         0
# 889         889  30.0000         1
# 890         890   7.7500         0
#
# [891 rows x 3 columns]

# %% [markdown]
# ## 4. Fetch specific rows of data of the titanic data

# %% [markdown]
# Fetch all the second class passengers of the titanic data and put them in a new `DataFrame` and show it.

# %%
secondClass = titanic[titanic['Pclass'] ==2]
secondClass
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ..                                            ...     ...   ...    ...    ...
# 866                  Duran y More, Miss. Asuncion  female  27.0      1      0
# 874         Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1      0
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 886                         Montvila, Rev. Juozas    male  27.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 9              237736  30.0708   NaN        C
# 15             248706  16.0000   NaN        S
# 17             244373  13.0000   NaN        S
# 20             239865  26.0000   NaN        S
# 21             248698  13.0000   D56        S
# ..                ...      ...   ...      ...
# 866     SC/PARIS 2149  13.8583   NaN        C
# 874         P/PP 3381  24.0000   NaN        C
# 880            230433  26.0000   NaN        S
# 883  C.A./SOTON 34068  10.5000   NaN        S
# 886            211536  13.0000   NaN        S
#
# [184 rows x 12 columns]

# %% [markdown]
# Fetch all the first and third class passengers, put them in a new `DataFrame`, and show it.

# %%
firstAndThird = titanic[(titanic['Pclass'] ==2 ) | (titanic['Pclass'] == 2)]
firstAndThird
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ..                                            ...     ...   ...    ...    ...
# 866                  Duran y More, Miss. Asuncion  female  27.0      1      0
# 874         Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1      0
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0      1
# 883                 Banfield, Mr. Frederick James    male  28.0      0      0
# 886                         Montvila, Rev. Juozas    male  27.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 9              237736  30.0708   NaN        C
# 15             248706  16.0000   NaN        S
# 17             244373  13.0000   NaN        S
# 20             239865  26.0000   NaN        S
# 21             248698  13.0000   D56        S
# ..                ...      ...   ...      ...
# 866     SC/PARIS 2149  13.8583   NaN        C
# 874         P/PP 3381  24.0000   NaN        C
# 880            230433  26.0000   NaN        S
# 883  C.A./SOTON 34068  10.5000   NaN        S
# 886            211536  13.0000   NaN        S
#
# [184 rows x 12 columns]

# %% [markdown]
# ## 5. Plot some Titanic data

# %% [markdown]
# First, import `matplotlib`

# %%
import matplotlib as plt

# %% [markdown]
# ### 5.a - Scatter plot

# %% [markdown]
# Make a scatter plot of fare vs. cabin class (seems like these should be perfectly related).

# %%
titanic.plot.scatter(x="Pclass", y="Fare", alpha = 0.3)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ### 5.b - Distribution plot (challenging!)

# %% [markdown]
# Plot the distributions of fare paid for survivors and deceased in a way that makes for a good visual comparison.

# %%
import matplotlib.pyplot as plt

survived = titanic[titanic['Survived'] == 1]  
died = titanic[titanic['Survived'] == 0] 

plt.hist(died['Fare'], bins = 30, color = 'b', edgecolor = 'b', alpha = 0.3, label = 'Died');
plt.hist(survived['Fare'], bins = 30, color = 'y', edgecolor = 'y', alpha = 0.3, label = 'Survived');

plt.xlabel('Fare Paid')
plt.ylabel('Number of People')
plt.legend()

# %% [markdown]
# ## 6. Calculate new columns

# %% [markdown]
# ### 6.a - Compute total number of relatives
# Create a new column in your titanic `DataFrame` quantifying the total number of relatives on board (siblings + parents – the number of siblings are in `SibSp` and the number of parents are in `Parch`).

# %%
titanic['relatives'] = titanic['Parch'] + titanic['SibSp']
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  relatives
# 0        0         A/5 21171   7.2500   NaN        S          1
# 1        0          PC 17599  71.2833   C85        C          1
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0
# 3        0            113803  53.1000  C123        S          1
# 4        0            373450   8.0500   NaN        S          0
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S          0
# 887      0            112053  30.0000   B42        S          0
# 888      2        W./C. 6607  23.4500   NaN        S          3
# 889      0            111369  30.0000  C148        C          0
# 890      0            370376   7.7500   NaN        Q          0
#
# [891 rows x 13 columns]

# %% [markdown]
# ### 6.b - Did a person have any relatives on board?
# Add another column – a Boolean column – indicating whether each person had any relatives on board.

# %%
titanic['relatives?'] = titanic['relatives'] > 1
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  relatives  relatives?
# 0        0         A/5 21171   7.2500   NaN        S          1       False
# 1        0          PC 17599  71.2833   C85        C          1       False
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0       False
# 3        0            113803  53.1000  C123        S          1       False
# 4        0            373450   8.0500   NaN        S          0       False
# ..     ...               ...      ...   ...      ...        ...         ...
# 886      0            211536  13.0000   NaN        S          0       False
# 887      0            112053  30.0000   B42        S          0       False
# 888      2        W./C. 6607  23.4500   NaN        S          3        True
# 889      0            111369  30.0000  C148        C          0       False
# 890      0            370376   7.7500   NaN        Q          0       False
#
# [891 rows x 14 columns]

# %% [markdown]
# ## 7. Computing descriptive statistics

# %% [markdown]
# ### 7.a - Compute a mean for a column

# %% [markdown]
# Compute the proportion of survivors of the RMS Titanic. **Hint**: the coding of `Survival` as 0 or 1 really works to our advantage here: the proportion of survivors in any group is easily computed using a common statistical function. The 7.a section header should also give you a big clue!

# %%
titanic['Survived'].mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# ### 7.a - Compute a mean for a subset of data

# %% [markdown]
# Compute the proportion of survivors for the females on the RMS Titanic (you can do this in one go, or two steps, using an intermediate object containing just the female data).

# %%
females = titanic[titanic['Sex'] == 'female']
females['Survived'].mean()
# Out:
# 0.7420382165605095

# %% [markdown]
# ### 7.b - Compute statistics by group

# %% [markdown]
# Compute the proportion of female vs. male survivors of the RMS Titanic.

# %%
females = titanic[titanic['Sex'] == 'female']
females['Survived'].mean()

males = titanic[titanic['Sex'] == 'male']
males['Survived'].mean()
# Out:
# 0.18890814558058924

# %%
females['Survived'].mean()/males['Survived'].mean()
# Out:
# 3.928037164728569

# %% [markdown]
# Now compute the proportion of female vs. male survivors of the RMS Titanic, *along with the **s**tandard **e**rror of the **m**ean*. The **bold** type should give you a hint about the name of the method to compute the standard error. To do this, you'll need to combine the `groupby()` and `agg()` methods!

# %%
sex_dif = titanic[['Survived', 'Sex']].groupby('Sex').mean()

titanic_dict = {
         "Survived": ["mean", "std", "sem"]
     }

sex_dif.agg(titanic_dict)
# Out:
#       Survived
# mean  0.465473
# std   0.391122
# sem   0.276565

# %% [markdown]
# What does this tell you about gender roles when the RMS Titanic was sunk?

# %% [markdown]
# **They probably tried to save the women first**

# %% [markdown]
# Compute the proportion of survivors by cabin class and their standard error.

# %%
FirstClass = titanic[titanic['Pclass'] == 1]
FirstClass['Survived'].mean()

SecondClass = titanic[titanic['Pclass'] == 2]
SecondClass['Survived'].mean()

ThirdClass = titanic[titanic['Pclass'] == 3]
ThirdClass['Survived'].mean()
# Out:
# 0.24236252545824846

# %%
class_dif = titanic[['Survived', 'Pclass']].groupby('Pclass').mean()

titanic_dict = {
         "Survived": ["mean", "std", "sem"]
     }

class_dif.agg(titanic_dict)
# Out:
#       Survived
# mean  0.448273
# std   0.194798
# sem   0.112466

# %% [markdown]
# What does this tell you about socio-economic status when the RMS Titanic was sunk?

# %% [markdown]
# **Higher-class passengers were probably given priority to lifeboats**
